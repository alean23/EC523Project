# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, ReLU, Concatenate
from tensorflow.keras.utils import to_categorical
import tensorflow as tf

# %%
# Load and preprocess the data
data = pd.read_csv('../final_combined_with_team_records.csv')
data = data.fillna(0)

def get_result(row):
    if row['home_team_goal'] > row['away_team_goal']:
        return 0
    elif row['home_team_goal'] == row['away_team_goal']:
        return 1
    else:
        return 2

data['result'] = data.apply(get_result, axis=1)
labels = to_categorical(data['result'], num_classes=3)

feature_columns = ['avg_home_prob', 'avg_draw_prob', 'avg_away_prob']

for i in range(1, 12):
    feature_columns += [f'home_player_{i}_rating', f'home_player_{i}_potential']
    feature_columns += [f'away_player_{i}_rating', f'away_player_{i}_potential']

record_columns = ['home_team_wins', 'home_team_draws', 'home_team_losses',
                  'away_team_wins', 'away_team_draws', 'away_team_losses']
for col in record_columns:
    if col in data.columns:
        feature_columns.append(col)

features = data[feature_columns].copy()

# %%
# Split into model input parts
home_features = features[[f'home_player_{i}_rating' for i in range(1, 12)] + [f'home_player_{i}_potential' for i in range(1, 12)]]
away_features = features[[f'away_player_{i}_rating' for i in range(1, 12)] + [f'away_player_{i}_potential' for i in range(1, 12)]]
context_features = features.drop(columns=home_features.columns.tolist() + away_features.columns.tolist())

# Train-test split
X_home_train, X_home_test, X_away_train, X_away_test, X_ctx_train, X_ctx_test, y_train, y_test = train_test_split(
    home_features, away_features, context_features, labels, test_size=0.2, random_state=42
)

# %%
# Normalize features
scaler_home = StandardScaler().fit(X_home_train)
scaler_away = StandardScaler().fit(X_away_train)
scaler_ctx = StandardScaler().fit(X_ctx_train)

X_home_train = scaler_home.transform(X_home_train)
X_away_train = scaler_away.transform(X_away_train)
X_ctx_train = scaler_ctx.transform(X_ctx_train)
X_home_test = scaler_home.transform(X_home_test)
X_away_test = scaler_away.transform(X_away_test)
X_ctx_test = scaler_ctx.transform(X_ctx_test)

# %%
# Define model
input_home = Input(shape=(X_home_train.shape[1],))
home_encoded = Dense(64)(input_home)
home_encoded = BatchNormalization()(home_encoded)
home_encoded = ReLU()(home_encoded)
home_encoded = Dropout(0.1)(home_encoded)

input_away = Input(shape=(X_away_train.shape[1],))
away_encoded = Dense(64)(input_away)
away_encoded = BatchNormalization()(away_encoded)
away_encoded = ReLU()(away_encoded)
away_encoded = Dropout(0.1)(away_encoded)

input_ctx = Input(shape=(X_ctx_train.shape[1],))
ctx_encoded = Dense(64)(input_ctx)
ctx_encoded = BatchNormalization()(ctx_encoded)
ctx_encoded = ReLU()(ctx_encoded)
ctx_encoded = Dropout(0.1)(ctx_encoded)

combined = Concatenate()([home_encoded, away_encoded, ctx_encoded])
output = Dense(64)(combined)
output = BatchNormalization()(output)
output = ReLU()(output)
output = Dropout(0.2)(output)
output = Dense(3, activation='softmax')(output)

model = Model(inputs=[input_home, input_away, input_ctx], outputs=output)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train
model.fit([X_home_train, X_away_train, X_ctx_train], y_train, 
          validation_split=0.2, epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4477 - loss: 1.1706 - val_accuracy: 0.4949 - val_loss: 1.0091
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5473 - loss: 0.9670 - val_accuracy: 0.4867 - val_loss: 0.9977
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5608 - loss: 0.9477 - val_accuracy: 0.5072 - val_loss: 1.0044
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5591 - loss: 0.9543 - val_accuracy: 0.5092 - val_loss: 1.0017
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5704 - loss: 0.9232 - val_accuracy: 0.5277 - val_loss: 1.0021
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6037 - loss: 0.8769 - val_accuracy: 0.5236 - val_loss: 0.9919
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5949 - loss: 0.9029 - val_accuracy: 0.5298 - val_loss: 1.0081
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5967 - loss: 0.8865 - val_accuracy: 0.5236 - val_loss: 1.0079
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5834 - loss: 0.8844 - val_accuracy: 0.5277 - val_loss: 1.0047
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6076 - loss: 0.8704 - val_accuracy: 0.5216 - val_loss: 1.0071
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5893 - loss: 0.8830 - val_accuracy: 0.5216 - val_loss: 1.0122
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6238 - loss: 0.8485 - val_accuracy: 0.5257 - val_loss: 1.0103
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6219 - loss: 0.8578 - val_accuracy: 0.5133 - val_loss: 1.0115
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6260 - loss: 0.8496 - val_accuracy: 0.5175 - val_loss: 1.0146
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6081 - loss: 0.8467 - val_accuracy: 0.5133 - val_loss: 1.0168
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6061 - loss: 0.8272 - val_accuracy: 0.5195 - val_loss: 1.0159
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6272 - loss: 0.8429 - val_accuracy: 0.5051 - val_loss: 1.0274
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6104 - loss: 0.8454 - val_accuracy: 0.5051 - val_loss: 1.0286
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6316 - loss: 0.8124 - val_accuracy: 0.5113 - val_loss: 1.0318
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6312 - loss: 0.8242 - val_accuracy: 0.5154 - val_loss: 1.0454
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6527 - loss: 0.8059 - val_accuracy: 0.5175 - val_loss: 1.0413
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6379 - loss: 0.8216 - val_accuracy: 0.4990 - val_loss: 1.0413
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6443 - loss: 0.7856 - val_accuracy: 0.5031 - val_loss: 1.0519
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6463 - loss: 0.7883 - val_accuracy: 0.4969 - val_loss: 1.0629
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6481 - loss: 0.7834 - val_accuracy: 0.5031 - val_loss: 1.0605
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6517 - loss: 0.7927 - val_accuracy: 0.5092 - val_loss: 1.0743
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6700 - loss: 0.7513 - val_accuracy: 0.5113 - val_loss: 1.0583
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6441 - loss: 0.7847 - val_accuracy: 0.5092 - val_loss: 1.0628
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6662 - loss: 0.7523 - val_accuracy: 0.5175 - val_loss: 1.0548
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6726 - loss: 0.7580 - val_accuracy: 0.5277 - val_loss: 1.0483
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6946 - loss: 0.7339 - val_accuracy: 0.5010 - val_loss: 1.0594
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6645 - loss: 0.7511 - val_accuracy: 0.4969 - val_loss: 1.0842
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6754 - loss: 0.7341 - val_accuracy: 0.5195 - val_loss: 1.0781
# Epoch 34/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6765 - loss: 0.7524 - val_accuracy: 0.5010 - val_loss: 1.0860
# Epoch 35/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6668 - loss: 0.7552 - val_accuracy: 0.5092 - val_loss: 1.0893
# Epoch 36/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6996 - loss: 0.7399 - val_accuracy: 0.5010 - val_loss: 1.0938
# Epoch 37/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6874 - loss: 0.7227 - val_accuracy: 0.4949 - val_loss: 1.0954
# Epoch 38/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6821 - loss: 0.7637 - val_accuracy: 0.5092 - val_loss: 1.0990
# Epoch 39/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6829 - loss: 0.7299 - val_accuracy: 0.5072 - val_loss: 1.1000
# Epoch 40/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6944 - loss: 0.7125 - val_accuracy: 0.4969 - val_loss: 1.1182
# Epoch 41/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7030 - loss: 0.6992 - val_accuracy: 0.4887 - val_loss: 1.1076
# Epoch 42/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6799 - loss: 0.7319 - val_accuracy: 0.4969 - val_loss: 1.1095
# Epoch 43/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7212 - loss: 0.6683 - val_accuracy: 0.4990 - val_loss: 1.1182
# Epoch 44/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6858 - loss: 0.7078 - val_accuracy: 0.5010 - val_loss: 1.1250
# Epoch 45/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7075 - loss: 0.6806 - val_accuracy: 0.4887 - val_loss: 1.1210
# Epoch 46/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6929 - loss: 0.7070 - val_accuracy: 0.4949 - val_loss: 1.1135
# Epoch 47/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7008 - loss: 0.6986 - val_accuracy: 0.4908 - val_loss: 1.1151
# Epoch 48/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6950 - loss: 0.7098 - val_accuracy: 0.4949 - val_loss: 1.1176
# Epoch 49/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7386 - loss: 0.6577 - val_accuracy: 0.5051 - val_loss: 1.1236
# Epoch 50/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7134 - loss: 0.6747 - val_accuracy: 0.5051 - val_loss: 1.1439

# %%
test_loss, test_acc = model.evaluate([X_home_test, X_away_test, X_ctx_test], y_test)
print("Test Accuracy:", test_acc)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5235 - loss: 1.1329
# Test Accuracy: 0.5180920958518982

# %%
# Evaluate model
test_loss, test_acc = model.evaluate([X_home_test, X_away_test, X_ctx_test], y_test)
print("Test Accuracy:", test_acc)

from sklearn.metrics import precision_recall_fscore_support, accuracy_score
import numpy as np

y_pred_probs = model.predict([X_home_test, X_away_test, X_ctx_test])
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision, recall, f1, support = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average=None, labels=[0, 1, 2]
)
macro_precision, macro_recall, macro_f1, _ = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average='macro'
)

print(f"\nTest Accuracy: {accuracy:.4f}")
print(f"Macro Precision: {macro_precision:.4f}")
print(f"Macro Recall: {macro_recall:.4f}")
print(f"Macro F1 Score: {macro_f1:.4f}\n")

for i, (p, r, f, s) in enumerate(zip(precision, recall, f1, support)):
    print(f"Class {i} — Precision: {p:.4f}, Recall: {r:.4f}, F1: {f:.4f}, Support: {s}")
